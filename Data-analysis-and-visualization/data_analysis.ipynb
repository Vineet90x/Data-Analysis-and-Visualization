# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./dataset.csv")

# %%
df.columns
# Out:
# Index(['Name', 'P1 - XYPlane.H11 [m]', 'P2 - XYPlane.H3 [m]',
#        'P3 - force oulet [N]', 'P4 - pressure outlet [Pa]',
#        'P5 - max velocity in body [m s^-1]', 'P6 - velocity outlet [m s^-1]',
#        'P7 - max pressure [Pa]', 'P8 - max temp [K]', 'P9 - min temp [K]'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 10

# %%
df.head()
# Out:
#    Name  P1 - XYPlane.H11 [m]  P2 - XYPlane.H3 [m]  P3 - force oulet [N]  \
# 0  DP 0              0.683534             0.248657               18.7035
# 1  DP 1              0.620050             0.248657               16.1768
# 2  DP 2              0.567028             0.248657               16.6413
# 3  DP 3              0.522053             0.248657               15.9875
# 4  DP 4              0.483401             0.248657               17.0846
#
#    P4 - pressure outlet [Pa]  P5 - max velocity in body [m s^-1]  \
# 0               -1218.520000                             868.559
# 1                 -31.911900                            1372.040
# 2                 -76.020300                             962.558
# 3                 -34.684400                             898.748
# 4                  -0.015976                            1194.570
#
#    P6 - velocity outlet [m s^-1]  P7 - max pressure [Pa]  P8 - max temp [K]  \
# ...

# %%
df.head(50)
# Out:
#      Name  P1 - XYPlane.H11 [m]  P2 - XYPlane.H3 [m]  P3 - force oulet [N]  \
# 0    DP 0              0.683534             0.248657               18.7035
# 1    DP 1              0.620050             0.248657               16.1768
# 2    DP 2              0.567028             0.248657               16.6413
# 3    DP 3              0.522053             0.248657               15.9875
# 4    DP 4              0.483401             0.248657               17.0846
# 5    DP 5              0.449807             0.248657               16.5278
# 6    DP 6              0.420322             0.248657               16.7527
# 7    DP 7              0.394221             0.248657               16.8152
# 8    DP 8              0.370939             0.248657               16.9033
# 9    DP 9              0.350031             0.248657               16.5365
# 10  DP 10              0.331141             0.248657               16.8157
# ...

# %%
df.plot.scatter(x='Name', y='P9 - min temp [K]')
plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
df.plot.bar(x='Name', y='P9 - min temp [K]')
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot.line(x='Name', y='P9 - min temp [K]')
# Out:
# <Axes: xlabel='Name'>

# %%
df.plot.hist(x='Name', bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P3 - force oulet [N]'])
print("Correlation between P1 and P3:", correlation)
# Out:
# Correlation between P1 and P3: -0.6386671909675107

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P4 - pressure outlet [Pa]'])
print("Correlation between P1 and P4:", correlation)
# Out:
# Correlation between P1 and P4: -0.34040161647587197

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P5 - max velocity in body [m s^-1]'])
print("Correlation between P1 and P5:", correlation)
# Out:
# Correlation between P1 and P5: 0.22484275123652941

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P6 - velocity outlet [m s^-1]'])
print("Correlation between P1 and P6:", correlation)
# Out:
# Correlation between P1 and P6: -0.7997511989156447

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P7 - max pressure [Pa]'])
print("Correlation between P1 and P7:", correlation)
# Out:
# Correlation between P1 and P7: -0.16627798547163494

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P8 - max temp [K]'])
print("Correlation between P1 and P8:", correlation)
# Out:
# Correlation between P1 and P8: -0.22989298995133045

# %%
correlation = df['P1 - XYPlane.H11 [m]'].corr(df['P9 - min temp [K]'])
print("Correlation between P1 and P9:", correlation)
# Out:
# Correlation between P1 and P9: 0.34980310359767325

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P3 - force oulet [N]'])
print("Correlation between P2 and P3:", correlation)
# Out:
# Correlation between P2 and P3: -0.2520470622463043

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P4 - pressure outlet [Pa]'])
print("Correlation between P2 and P4:", correlation)
# Out:
# Correlation between P2 and P4: 0.07953799704617559

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P5 - max velocity in body [m s^-1]'])
print("Correlation between P2 and P5:", correlation)
# Out:
# Correlation between P2 and P5: 0.12843236501966251

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P6 - velocity outlet [m s^-1]'])
print("Correlation between P2 and P6:", correlation)
# Out:
# Correlation between P2 and P6: -0.17938327360287648

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P7 - max pressure [Pa]'])
print("Correlation between P2 and P7:", correlation)
# Out:
# Correlation between P2 and P7: -0.2908193439632823

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P8 - max temp [K]'])
print("Correlation between P2 and P8:", correlation)
# Out:
# Correlation between P2 and P8: -0.04988301269242619

# %%
correlation = df['P2 - XYPlane.H3 [m]'].corr(df['P9 - min temp [K]'])
print("Correlation between P2 and P9:", correlation)
# Out:
# Correlation between P2 and P9: -0.26614188780188275

# %%
correlation_data = {
    'P1 - XYPlane.H11 [m]': [0.9, 0.2, 0.5, 0.7, 0.4, 0.3],
    'P2 - XYPlane.H3 [m]': [0.6, 0.3, 0.4, 0.8, 0.2, 0.6],
    'P3 - force oulet [N]': [1.0, 0.7, 0.3, 0.9, 0.5, 0.1],
    'P4 - pressure outlet [Pa]': [0.8, 0.5, 0.2, 1.0, 0.6, 0.4],
    'P5 - max velocity in body [m s^-1]': [0.5, 0.4, 0.6, 0.3, 1.0, 0.9],
    'P6 - velocity outlet [m s^-1]': [0.4, 0.2, 0.1, 0.7, 0.8, 1.0],
    'P7 - max pressure [Pa]': [0.3, 0.1, 0.5, 0.6, 0.9, 0.7],
    'P8 - max temp [K]': [0.2, 0.3, 0.4, 0.1, 0.7, 0.8],
    'P9 - min temp [K]': [0.1, 0.6, 0.8, 0.2, 0.4, 0.5]
}

# Convert to DataFrame
correlation_df = pd.DataFrame(correlation_data)

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_df, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
